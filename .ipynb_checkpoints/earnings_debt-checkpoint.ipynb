# %%
import pandas as pd
import numpy as np
import sklearn.metrics
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

from sklearn.preprocessing import PolynomialFeatures 

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from scipy.sparse import csr_matrix, hstack

import tensorflow as tf
import keras
import time
from keras.models import Sequential

from sklearn.model_selection import GridSearchCV
# Out:
# Using TensorFlow backend.

# %%
df_96 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED1996_97_PP.csv")
df_97 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED1997_98_PP.csv")
df_98 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED1998_99_PP.csv")
df_99 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED1999_00_PP.csv")
df_00 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2000_01_PP.csv")
df_01 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2001_02_PP.csv")
df_02 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2002_03_PP.csv")
df_03 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2003_04_PP.csv")
df_04 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2004_05_PP.csv")
df_05 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2005_06_PP.csv")
df_06 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2006_07_PP.csv")
df_07 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2007_08_PP.csv")
df_08 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2008_09_PP.csv")
df_09 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2009_10_PP.csv")
df_10 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2010_11_PP.csv")
df_11 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2011_12_PP.csv")
df_12 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2012_13_PP.csv")
df_13 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2013_14_PP.csv")
df_14 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2014_15_PP.csv")
df_15 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2015_16_PP.csv")
df_16 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2016_17_PP.csv")
df_17 = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2017_18_PP.csv")
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1806,1814) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,6,442,451,598,607,611,620,624,633,789,802,806,815,971,984,997,1153,1166,1407,1408,1411,1424,1425,1426,1431,1432,1433,1437,1438,1439,1440,1445,1446,1447,1451,1452,1453,1454,1459,1460,1461,1465,1466,1467,1468,1473,1474,1475,1479,1480,1481,1482,1487,1488,1489,1501,1502,1537,1538,1539,1540,1541,1542,1606,1609,1610,1611,1613,1614,1615,1616,1688,1689,1690,1691,1692,1908,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,1408,1431,1432,1433,1489,1537,1538,1539,1540,1542,1606,1610,1611,1614,1615,1616,1729) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,1447,1537,1540,1542,1606,1614,1615) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,1537,1540,1542,1606,1614,1615) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,6,1461,1561,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1537,1540,1542,1575,1606,1614,1615,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1537,1540,1542,1547,1548,1549,1561,1575,1606,1614,1615,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,1169,1170,1171,1172,1173,1174,1175,1177,1178,1179,1180,1183,1184,1185,1186,1187,1188,1196,1199,1200,1209,1212,1213,1222,1223,1224,1225,1226,1227,1235,1236,1237,1238,1239,1240,1248,1251,1252,1253,1255,1257,1261,1264,1265,1266,1268,1270,1274,1275,1276,1277,1278,1279,1281,1287,1288,1289,1290,1291,1292,1294,1303,1304,1316,1317,1326,1327,1328,1329,1330,1331,1335,1339,1340,1341,1342,1343,1344,1348,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1411,1426,1427,1475,1476,1479,1480,1483,1484,1487,1488,1489,1490,1491,1492,1493,1494,1495,1496,1497,1498,1499,1500,1501,1502,1503,1517,1529,1530,1532,1537,1540,1541,1542,1575,1576,1577,1578,1579,1580,1581,1582,1583,1584,1585,1586,1587,1588,1589,1590,1591,1592,1593,1594,1595,1596,1597,1598,1599,1600,1601,1602,1606,1609,1610,1613,1614,1615,1708,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1408,1431,1432,1503,1504,1517,1518,1519,1529,1530,1531,1532,1534,1535,1537,1538,1539,1540,1542,1575,1576,1577,1578,1579,1580,1581,1582,1583,1584,1585,1586,1587,1588,1589,1590,1591,1592,1593,1594,1595,1596,1597,1598,1599,1600,1601,1602,1606,1610,1611,1614,1615,1616,1708,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (31,1726,1727,1728,1729,1815,1817,1823,1830,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frames = [
    df_96, df_97, df_98, 
    df_99, df_00, df_01, 
    df_02, df_03, df_04, 
    df_05, df_06, df_07, 
    df_08, df_09, df_10,
    df_11, df_12, df_13, 
    df_14, df_15, df_16, df_17
]
data = pd.concat(frames)

# %%
data['MD_EARN_WNE_P10'].describe()
# Out:
# count                 40216
# unique                  921
# top       PrivacySuppressed
# freq                   5373
# Name: MD_EARN_WNE_P10, dtype: object

# %%
data['GRAD_DEBT_MDN'].describe()
# Out:
# count                137486
# unique                21488
# top       PrivacySuppressed
# freq                  35382
# Name: GRAD_DEBT_MDN, dtype: object

# %%
print(data.shape)
data = data.set_index('UNITID')
data.head()
# Out:
# (154282, 1977)
#            OPEID  OPEID6                                  INSTNM        CITY  \
# UNITID
# 100636  01230800   12308      Community College of the Air Force  Montgomery
# 100654  00100200    1002                Alabama A & M University      Normal
# 100663  00105200    1052     University of Alabama at Birmingham  Birmingham
# 100672  00574900    5749  ALABAMA AVIATION AND TECHNICAL COLLEGE       OZARK
# 100690  02503400   25034                      Amridge University  Montgomery
#
#        STABBR         ZIP ACCREDAGENCY INSTURL NPCURL  SCH_DEG  ...  \
# UNITID                                                          ...
# 100636     AL  36114-3011          NaN     NaN    NaN      NaN  ...
# 100654     AL       35762          NaN     NaN    NaN      NaN  ...
# 100663     AL  35294-0110          NaN     NaN    NaN      NaN  ...
# 100672     AL       36360          NaN     NaN    NaN      NaN  ...
# 100690     AL  36117-3553          NaN     NaN    NaN      NaN  ...
#
#         OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# UNITID
# 100636                               NaN                               NaN
# 100654                               NaN                               NaN
# 100663                               NaN                               NaN
# 100672                               NaN                               NaN
# 100690                               NaN                               NaN
#
#         OMENRYP_FULLTIME_POOLED_SUPP  OMENRAP_FULLTIME_POOLED_SUPP  \
# UNITID
# 100636                           NaN                           NaN
# 100654                           NaN                           NaN
# 100663                           NaN                           NaN
# 100672                           NaN                           NaN
# 100690                           NaN                           NaN
#
#         OMAWDP8_FULLTIME_POOLED_SUPP  OMENRUP_FULLTIME_POOLED_SUPP  \
# UNITID
# 100636                           NaN                           NaN
# 100654                           NaN                           NaN
# 100663                           NaN                           NaN
# 100672                           NaN                           NaN
# 100690                           NaN                           NaN
#
#         OMENRYP_PARTTIME_POOLED_SUPP  OMENRAP_PARTTIME_POOLED_SUPP  \
# UNITID
# 100636                           NaN                           NaN
# 100654                           NaN                           NaN
# 100663                           NaN                           NaN
# 100672                           NaN                           NaN
# 100690                           NaN                           NaN
#
#         OMAWDP8_PARTTIME_POOLED_SUPP  OMENRUP_PARTTIME_POOLED_SUPP
# UNITID
# 100636                           NaN                           NaN
# 100654                           NaN                           NaN
# 100663                           NaN                           NaN
# 100672                           NaN                           NaN
# 100690                           NaN                           NaN
#
# [5 rows x 1976 columns]

# %%
data = data.replace('PrivacySuppressed', np.nan)
data = data.replace('null', np.nan)
print(data.shape)
# Out:
# (154282, 1976)

# %%
cols_to_remove = [
    #irrelevant data
    'OPEID',
    'OPEID6',
    'INSTNM',
    'ZIP',
    'INSTURL',
    'NPCURL',
    'LATITUDE',
    'LONGITUDE',
    'ALIAS',
    'CIPTITLE1',
    'CIPTITLE2',
    'CIPTITLE3',
    'CIPTITLE4',
    'CIPTITLE5',
    'CIPTITLE6',
    
    #date fields:
    'REPAY_DT_MDN',
    'SEPAR_DT_MDN',
    'T4APPROVALDATE',
    
    #earnings data
    'COUNT_ED',
    'COUNT_NWNE_P10',
    'COUNT_WNE_P10',
    'MN_EARN_WNE_P10',
    'PCT10_EARN_WNE_P10',
    'PCT25_EARN_WNE_P10',
    'PCT75_EARN_WNE_P10',
    'PCT90_EARN_WNE_P10',
    'SD_EARN_WNE_P10',
    'COUNT_WNE_INC1_P10',
    'COUNT_WNE_INC2_P10',
    'COUNT_WNE_INC3_P10',
    'COUNT_WNE_INDEP0_INC1_P10',
    'COUNT_WNE_INDEP0_P10',
    'COUNT_WNE_INDEP1_P10',
    'COUNT_WNE_MALE0_P10',
    'COUNT_WNE_MALE1_P10',
    'GT_25K_P10',
    'GT_28K_P10',
    'MN_EARN_WNE_INC1_P10',
    'MN_EARN_WNE_INC2_P10',
    'MN_EARN_WNE_INC3_P10',
    'MN_EARN_WNE_INDEP0_INC1_P10',
    'MN_EARN_WNE_INDEP0_P10',
    'MN_EARN_WNE_INDEP1_P10',
    'MN_EARN_WNE_MALE0_P10',
    'MN_EARN_WNE_MALE1_P10',
    'COUNT_NWNE_P6',
    'COUNT_WNE_P6',
    'MN_EARN_WNE_P6',
    'MD_EARN_WNE_P6',
    'PCT10_EARN_WNE_P6',
    'PCT25_EARN_WNE_P6',
    'PCT75_EARN_WNE_P6',
    'PCT90_EARN_WNE_P6',
    'SD_EARN_WNE_P6',
    'COUNT_WNE_INC1_P6',
    'COUNT_WNE_INC2_P6',
    'COUNT_WNE_INC3_P6',
    'COUNT_WNE_INDEP0_INC1_P6',
    'COUNT_WNE_INDEP0_P6',
    'COUNT_WNE_INDEP1_P6',
    'COUNT_WNE_MALE0_P6',
    'COUNT_WNE_MALE1_P6',
    'GT_25K_P6',
    'GT_28K_P6',
    'MN_EARN_WNE_INC1_P6',
    'MN_EARN_WNE_INC2_P6',
    'MN_EARN_WNE_INC3_P6',
    'MN_EARN_WNE_INDEP0_INC1_P6',
    'MN_EARN_WNE_INDEP0_P6',
    'MN_EARN_WNE_INDEP1_P6',
    'MN_EARN_WNE_MALE0_P6',
    'MN_EARN_WNE_MALE1_P6',
    'COUNT_NWNE_P7',
    'COUNT_WNE_P7',
    'MN_EARN_WNE_P7',
    'SD_EARN_WNE_P7',
    'GT_25K_P7',
    'COUNT_NWNE_P8',
    'COUNT_WNE_P8',
    'MN_EARN_WNE_P8',
    'MD_EARN_WNE_P8',
    'PCT10_EARN_WNE_P8',
    'PCT25_EARN_WNE_P8',
    'PCT75_EARN_WNE_P8',
    'PCT90_EARN_WNE_P8',
    'SD_EARN_WNE_P8',
    'GT_25K_P8',
    'GT_28K_P8',
    'COUNT_NWNE_P9',
    'COUNT_WNE_P9',
    'MN_EARN_WNE_P9',
    'SD_EARN_WNE_P9',
    'GT_25K_P9',
    
    #aid:
    'PCTPELL',
    'PCTFLOAN',
    'DEBT_MDN',
    'WDRAW_DEBT_MDN',
    'LO_INC_DEBT_MDN',
    'MD_INC_DEBT_MDN',
    'HI_INC_DEBT_MDN',
    'DEP_DEBT_MDN',
    'IND_DEBT_MDN',
    'PELL_DEBT_MDN',
    'NOPELL_DEBT_MDN',
    'FEMALE_DEBT_MDN',
    'MALE_DEBT_MDN',
    'FIRSTGEN_DEBT_MDN',
    'NOTFIRSTGEN_DEBT_MDN',
    'DEBT_N',
    'GRAD_DEBT_N',
    'WDRAW_DEBT_N',
    'LO_INC_DEBT_N',
    'MD_INC_DEBT_N',
    'HI_INC_DEBT_N',
    'DEP_DEBT_N',
    'IND_DEBT_N',
    'PELL_DEBT_N',
    'NOPELL_DEBT_N',
    'FEMALE_DEBT_N',
    'MALE_DEBT_N',
    'FIRSTGEN_DEBT_N',
    'NOTFIRSTGEN_DEBT_N',
    'GRAD_DEBT_MDN10YR',
    'CUML_DEBT_N',
    'CUML_DEBT_P90',
    'CUML_DEBT_P75',
    'CUML_DEBT_P25',
    'CUML_DEBT_P10',
    'LOAN_EVER',
    'DEBT_MDN_SUPP',
    'GRAD_DEBT_MDN_SUPP',
    'GRAD_DEBT_MDN10YR_SUPP',
    
    #repayment
    'CDR2',
    'CDR3',
    'RPY_1YR_RT',
    'COMPL_RPY_1YR_RT',
    'NONCOM_RPY_1YR_RT',
    'LO_INC_RPY_1YR_RT',
    'MD_INC_RPY_1YR_RT',
    'HI_INC_RPY_1YR_RT',
    'DEP_RPY_1YR_RT',
    'IND_RPY_1YR_RT',
    'PELL_RPY_1YR_RT',
    'NOPELL_RPY_1YR_RT',
    'FEMALE_RPY_1YR_RT',
    'MALE_RPY_1YR_RT',
    'FIRSTGEN_RPY_1YR_RT',
    'NOTFIRSTGEN_RPY_1YR_RT',
    'RPY_3YR_RT',
    'COMPL_RPY_3YR_RT',
    'NONCOM_RPY_3YR_RT',
    'LO_INC_RPY_3YR_RT',
    'MD_INC_RPY_3YR_RT',
    'HI_INC_RPY_3YR_RT',
    'DEP_RPY_3YR_RT',
    'IND_RPY_3YR_RT',
    'PELL_RPY_3YR_RT',
    'NOPELL_RPY_3YR_RT',
    'FEMALE_RPY_3YR_RT',
    'MALE_RPY_3YR_RT',
    'FIRSTGEN_RPY_3YR_RT',
    'NOTFIRSTGEN_RPY_3YR_RT',
    'RPY_5YR_RT',
    'COMPL_RPY_5YR_RT',
    'NONCOM_RPY_5YR_RT',
    'LO_INC_RPY_5YR_RT',
    'MD_INC_RPY_5YR_RT',
    'HI_INC_RPY_5YR_RT',
    'DEP_RPY_5YR_RT',
    'IND_RPY_5YR_RT',
    'PELL_RPY_5YR_RT',
    'NOPELL_RPY_5YR_RT',
    'FEMALE_RPY_5YR_RT',
    'MALE_RPY_5YR_RT',
    'FIRSTGEN_RPY_5YR_RT',
    'NOTFIRSTGEN_RPY_5YR_RT',
    'RPY_7YR_RT',
    'COMPL_RPY_7YR_RT',
    'NONCOM_RPY_7YR_RT',
    'LO_INC_RPY_7YR_RT',
    'MD_INC_RPY_7YR_RT',
    'HI_INC_RPY_7YR_RT',
    'DEP_RPY_7YR_RT',
    'IND_RPY_7YR_RT',
    'PELL_RPY_7YR_RT',
    'NOPELL_RPY_7YR_RT',
    'FEMALE_RPY_7YR_RT',
    'MALE_RPY_7YR_RT',
    'FIRSTGEN_RPY_7YR_RT',
    'NOTFIRSTGEN_RPY_7YR_RT',
    'REPAY_DT_MDN',
    'REPAY_DT_N',
    'RPY_1YR_N',
    'COMPL_RPY_1YR_N',
    'NONCOM_RPY_1YR_N',
    'LO_INC_RPY_1YR_N',
    'MD_INC_RPY_1YR_N',
    'HI_INC_RPY_1YR_N',
    'DEP_RPY_1YR_N',
    'IND_RPY_1YR_N',
    'PELL_RPY_1YR_N',
    'NOPELL_RPY_1YR_N',
    'FEMALE_RPY_1YR_N',
    'MALE_RPY_1YR_N',
    'FIRSTGEN_RPY_1YR_N',
    'NOTFIRSTGEN_RPY_1YR_N',
    'RPY_3YR_N',
    'COMPL_RPY_3YR_N',
    'NONCOM_RPY_3YR_N',
    'LO_INC_RPY_3YR_N',
    'MD_INC_RPY_3YR_N',
    'HI_INC_RPY_3YR_N',
    'DEP_RPY_3YR_N',
    'IND_RPY_3YR_N',
    'PELL_RPY_3YR_N',
    'NOPELL_RPY_3YR_N',
    'FEMALE_RPY_3YR_N',
    'MALE_RPY_3YR_N',
    'FIRSTGEN_RPY_3YR_N',
    'NOTFIRSTGEN_RPY_3YR_N',
    'RPY_5YR_N',
    'COMPL_RPY_5YR_N',
    'NONCOM_RPY_5YR_N',
    'LO_INC_RPY_5YR_N',
    'MD_INC_RPY_5YR_N',
    'HI_INC_RPY_5YR_N',
    'DEP_RPY_5YR_N',
    'IND_RPY_5YR_N',
    'PELL_RPY_5YR_N',
    'NOPELL_RPY_5YR_N',
    'FEMALE_RPY_5YR_N',
    'MALE_RPY_5YR_N',
    'FIRSTGEN_RPY_5YR_N',
    'NOTFIRSTGEN_RPY_5YR_N',
    'RPY_7YR_N',
    'COMPL_RPY_7YR_N',
    'NONCOM_RPY_7YR_N',
    'LO_INC_RPY_7YR_N',
    'MD_INC_RPY_7YR_N',
    'HI_INC_RPY_7YR_N',
    'DEP_RPY_7YR_N',
    'IND_RPY_7YR_N',
    'PELL_RPY_7YR_N',
    'NOPELL_RPY_7YR_N',
    'FEMALE_RPY_7YR_N',
    'MALE_RPY_7YR_N',
    'FIRSTGEN_RPY_7YR_N',
    'NOTFIRSTGEN_RPY_7YR_N',
    'RPY_3YR_RT_SUPP',
    'LO_INC_RPY_3YR_RT_SUPP',
    'MD_INC_RPY_3YR_RT_SUPP',
    'HI_INC_RPY_3YR_RT_SUPP',
    'COMPL_RPY_3YR_RT_SUPP',
    'NONCOM_RPY_3YR_RT_SUPP',
    'DEP_RPY_3YR_RT_SUPP',
    'IND_RPY_3YR_RT_SUPP',
    'PELL_RPY_3YR_RT_SUPP',
    'NOPELL_RPY_3YR_RT_SUPP',
    'FEMALE_RPY_3YR_RT_SUPP',
    'MALE_RPY_3YR_RT_SUPP',
    'FIRSTGEN_RPY_3YR_RT_SUPP',
    'NOTFIRSTGEN_RPY_3YR_RT_SUPP',
    'CDR2_DENOM',
    'CDR3_DENOM'
]
data = data.drop(columns=cols_to_remove)

# %%
##Drop rows with nulls for our Y column
data = data.dropna(subset=['MD_EARN_WNE_P10','GRAD_DEBT_MDN'])
print(data.shape)
# Out:
# (31070, 1713)

# %%
print(data.shape)

data = data.dropna(axis='columns', how='all')
#data = data.dropna(axis=1, how='all')
print(data.shape)

data = data.dropna(axis='rows', how='all')
print(data.shape)

data.head()
# Out:
# (31070, 1713)
# (31070, 1482)
# (31070, 1482)
#               CITY STABBR  SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  \
# UNITID
# 100654      Normal     AL      3.0     1          1        3        4
# 100663  Birmingham     AL      3.0     1          1        3        4
# 100706  Huntsville     AL      3.0     1          1        3        4
# 100724  Montgomery     AL      3.0     1          1        3        4
# 100751  Tuscaloosa     AL      3.0     1          1        3        4
#
#         CONTROL  ST_FIPS  REGION  ...  CIPTFBSANNUAL3  CIPTFBSANNUAL4  \
# UNITID                            ...
# 100654      1.0      1.0     5.0  ...             NaN             NaN
# 100663      1.0      1.0     5.0  ...             NaN             NaN
# 100706      1.0      1.0     5.0  ...             NaN             NaN
# 100724      1.0      1.0     5.0  ...             NaN             NaN
# 100751      1.0      1.0     5.0  ...             NaN             NaN
#
#         CIPTFBSANNUAL5  CIPTFBSANNUAL6  MTHCMP1  MTHCMP2  MTHCMP3  MTHCMP4  \
# UNITID
# 100654             NaN             NaN      NaN      NaN      NaN      NaN
# 100663             NaN             NaN      NaN      NaN      NaN      NaN
# 100706             NaN             NaN      NaN      NaN      NaN      NaN
# 100724             NaN             NaN      NaN      NaN      NaN      NaN
# 100751             NaN             NaN      NaN      NaN      NaN      NaN
#
#         MTHCMP5  MTHCMP6
# UNITID
# 100654      NaN      NaN
# 100663      NaN      NaN
# 100706      NaN      NaN
# 100724      NaN      NaN
# 100751      NaN      NaN
#
# [5 rows x 1482 columns]

# %%
data['MD_EARN_WNE_P10'].describe()
# Out:
# count     31070
# unique      832
# top       38800
# freq        373
# Name: MD_EARN_WNE_P10, dtype: object

# %%
data['GRAD_DEBT_MDN'].describe()
# Out:
# count     31070
# unique     8438
# top        9500
# freq       1995
# Name: GRAD_DEBT_MDN, dtype: object

# %%
cats = [
#index:'UNITID',
    
#commented out fields were empty due to removing rows/columns with all nan
'CITY',
'STABBR',
#'ACCREDAGENCY',
'SCH_DEG',
#'HCM2',
'MAIN',
'PREDDEG',
'HIGHDEG',
'CONTROL',
'ST_FIPS',
'REGION',
#'LOCALE',
#'LOCALE2',
#'CCBASIC',
#'CCUGPROF',
#'CCSIZSET',
#'HBCU',
#'PBI',
#'ANNHI',
#'TRIBAL',
#'AANAPII',
#'HSI',
#'NANTI',
#'MENONLY',
#'WOMENONLY',
#'RELAFFIL',
'DISTANCEONLY',
#'CURROPER',
'ICLEVEL',
'OPENADMP',
#'ACCREDCODE',
#'POOLYRSRET_FT',
#'POOLYRSRET_PT',
#'POOLYRS100',
#'POOLYRSOM_FTFT',
#'POOLYRSOM_PTFT',
#'POOLYRSOM_FTNFT',
#'POOLYRSOM_PTNFT',
#'SCHTYPE',
#'OPEFLAG',
'CIPCODE1',
'CIPCODE2',
'CIPCODE3',
'CIPCODE4',
'CIPCODE5',
'CIPCODE6',
#'POOLYRSOM_ALL',
#'POOLYRSOM_FIRSTTIME',
#'POOLYRSOM_NOTFIRSTTIME',
#'POOLYRSOM_FULLTIME',
#'POOLYRSOM_PARTTIME'
]

# %%
#convert columns into floats where possible, one-hot-encode others
#cats = []
for i in data.columns:
    if data[i].dtype == "object":
        try:
            data[i] = data[i].astype('float64')
            if data[i].mean() == np.nan:
                print("mean = null")
                print(i)
                data = data.drop(columns=i)
            else:
                data[i] = data[i].fillna(data[i].mean())
        except:
            #cats.append(i)
            if i not in cats:
                print("not in cats")
                print(i)
            data[i] = data[i].fillna("null")
    elif data[i].dtype == "float64":
        data[i] = data[i].fillna(data[i].mean())

# %%
y = data['MD_EARN_WNE_P10'] / data['GRAD_DEBT_MDN']
y = y.astype("float64")
X = data.drop(columns=['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN'])

# %%
y.describe()
# Out:
# count    31070.000000
# mean         2.821414
# std          2.353092
# min          0.486168
# 25%          1.687540
# 50%          2.357160
# 75%          3.329758
# max        110.350000
# dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
X_train.head()
# Out:
#              CITY STABBR  SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  \
# UNITID
# 101879   Florence     AL      3.0     1          1        3        4      1.0
# 198109    Concord     NC      2.0     1          1        2        3      2.0
# 189848  Cazenovia     NY      3.0     1          1        3        3      2.0
# 467793   Meridian     ID      2.0     0          5        2        0      3.0
# 148511    Chicago     IL      3.0     1          1        3        4      2.0
#
#         ST_FIPS  REGION  ...  CIPTFBSANNUAL3  CIPTFBSANNUAL4  CIPTFBSANNUAL5  \
# UNITID                   ...
# 101879      1.0     5.0  ...     10726.84578    10977.084807    11633.070485
# 198109     37.0     5.0  ...     10726.84578    10977.084807    11633.070485
# 189848     36.0     2.0  ...     10726.84578    10977.084807    11633.070485
# 467793     16.0     7.0  ...     10726.84578    10977.084807    11633.070485
# 148511     17.0     3.0  ...     10726.84578    10977.084807    11633.070485
#
#         CIPTFBSANNUAL6    MTHCMP1   MTHCMP2   MTHCMP3   MTHCMP4    MTHCMP5  \
# UNITID
# 101879    11652.804878  11.922673  9.721121  9.752101  10.21989  11.183434
# 198109    11652.804878  11.922673  9.721121  9.752101  10.21989  11.183434
# 189848    11652.804878  11.922673  9.721121  9.752101  10.21989  11.183434
# 467793    11652.804878  11.922673  9.721121  9.752101  10.21989  11.183434
# 148511    11652.804878  11.922673  9.721121  9.752101  10.21989  11.183434
#
#           MTHCMP6
# UNITID
# 101879  12.089223
# 198109  12.089223
# 189848  12.089223
# 467793  12.089223
# 148511  12.089223
#
# [5 rows x 1480 columns]

# %%
y_train.describe()
# Out:
# count    20816.000000
# mean         2.815109
# std          2.302905
# min          0.521951
# 25%          1.692936
# 50%          2.358170
# 75%          3.333702
# max        110.350000
# dtype: float64

# %%
### One Hot Encoding
enc = preprocessing.OneHotEncoder(handle_unknown='ignore')
enc.fit(X_train[cats])
ohe_train = enc.transform(X_train[cats])
ohe_test = enc.transform(X_test[cats])

# %%
ohe_train
# Out:
# <20816x3450 sparse matrix of type '<class 'numpy.float64'>'
# 	with 374688 stored elements in Compressed Sparse Row format>

# %%
### Scaling
scaler = StandardScaler()
scaler.fit(X_train.drop(columns=cats))
scaled_train = csr_matrix(scaler.transform(X_train.drop(columns=cats)))
scaled_test = csr_matrix(scaler.transform(X_test.drop(columns=cats)))

# %%
X_mat_train = hstack((ohe_train, scaled_train))
X_mat_test = hstack((ohe_test, scaled_test))
X_mat_train
# Out:
# <20816x4912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 30807680 stored elements in COOrdinate format>

# %%
#### Neural Network
mlp = MLPRegressor()
mlp.fit(X_mat_train, y_train)

mlp_train_pred = mlp.predict(X_mat_train)
mlp_pred = mlp.predict(X_mat_test)

print("Train MSE: " + str(mean_squared_error(y_train, mlp_train_pred)))
print("Train RMSE: " + str(np.sqrt(mean_squared_error(y_train, mlp_train_pred))))
print("Train MAE: " + str(mean_absolute_error(y_train, mlp_train_pred)))
print("Train r2: " + str(r2_score(y_train, mlp_train_pred)))
print()
print("Test MSE: " + str(mean_squared_error(y_test, mlp_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, mlp_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, mlp_pred)))
print("Test r2: " + str(r2_score(y_test, mlp_pred)))
# Out:
# Train MSE: 0.09111860351385076
# Train RMSE: 0.30185858197813553
# Train MAE: 0.15519993263420997
# Train r2: 0.9828179187184616
#
# Test MSE: 3.1151145492651127
# Test RMSE: 1.76496871056263
# Test MAE: 0.5689897439214676
# Test r2: 0.4817756937028863

# %%
### Ensemble Boosting
boost = GradientBoostingRegressor()
boost.fit(X_mat_train, y_train)

boost_train_pred = boost.predict(X_mat_train)
boost_pred = boost.predict(X_mat_test)

print("Train MSE: " + str(mean_squared_error(y_train, boost_train_pred)))
print("Train RMSE: " + str(np.sqrt(mean_squared_error(y_train, boost_train_pred))))
print("Train MAE: " + str(mean_absolute_error(y_train, boost_train_pred)))
print("Train r2: " + str(r2_score(y_train, boost_train_pred)))
print()
print("Test MSE: " + str(mean_squared_error(y_test, boost_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, boost_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, boost_pred)))
print("Test r2: " + str(r2_score(y_test, boost_pred)))
# Out:
# Train MSE: 0.8422058550590639
# Train RMSE: 0.9177177425870461
# Train MAE: 0.5897256902302139
# Train r2: 0.8411866633226799
#
# Test MSE: 1.8264271166662411
# Test RMSE: 1.3514537049659678
# Test MAE: 0.6528124513825833
# Test r2: 0.6961591907559582

# %%
### Ada Boosting
ada = AdaBoostRegressor()
ada.fit(X_mat_train, y_train)

ada_train_pred = ada.predict(X_mat_train)
ada_pred = ada.predict(X_mat_test)

print("Train MSE: " + str(mean_squared_error(y_train, ada_train_pred)))
print("Train RMSE: " + str(np.sqrt(mean_squared_error(y_train, ada_train_pred))))
print("Train MAE: " + str(mean_absolute_error(y_train, ada_train_pred)))
print("Train r2: " + str(r2_score(y_train, ada_train_pred)))
print()
print("Test MSE: " + str(mean_squared_error(y_test, ada_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, ada_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, ada_pred)))
print("Test r2: " + str(r2_score(y_test, ada_pred)))
# Out:
# Train MSE: 19.06858459279412
# Train RMSE: 4.36675904908825
# Train MAE: 4.113835848040013
# Train r2: -2.5957308141523123
#
# Test MSE: 20.00321213487631
# Test RMSE: 4.472495068177975
# Test MAE: 4.156425719418491
# Test r2: -2.3276948787503695

# %%
### Random Forest
rf = RandomForestRegressor()
rf.fit(X_mat_train, y_train)
rf_train_pred = rf.predict(X_mat_train)
rf_pred = rf.predict(X_mat_test)

print("Train MSE: " + str(mean_squared_error(y_train, rf_train_pred)))
print("Train RMSE: " + str(np.sqrt(mean_squared_error(y_train, rf_train_pred))))
print("Train MAE: " + str(mean_absolute_error(y_train, rf_train_pred)))
print("Train r2: " + str(r2_score(y_train, rf_train_pred)))
print()
print("Test MSE: " + str(mean_squared_error(y_test, rf_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, rf_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, rf_pred)))
print("Test r2: " + str(r2_score(y_test, rf_pred)))
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train MSE: 0.3579562816241645
# Train RMSE: 0.5982944773472044
# Train MAE: 0.194420827352999
# Train r2: 0.9325007881055953
#
# Test MSE: 1.8134793034636363
# Test RMSE: 1.3466548568447805
# Test MAE: 0.49154864338907095
# Test r2: 0.6983131633976922

# %%
### Bagging
bag = BaggingRegressor()
bag.fit(X_mat_train, y_train)

bag_train_pred = bag.predict(X_mat_train)
bag_pred = bag.predict(X_mat_test)

print("Train MSE: " + str(mean_squared_error(y_train, bag_train_pred)))
print("Train RMSE: " + str(np.sqrt(mean_squared_error(y_train, bag_train_pred))))
print("Train MAE: " + str(mean_absolute_error(y_train, bag_train_pred)))
print("Train r2: " + str(r2_score(y_train, bag_train_pred)))
print()
print("Test MSE: " + str(mean_squared_error(y_test, bag_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, bag_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, bag_pred)))
print("Test r2: " + str(r2_score(y_test, bag_pred)))
# Out:
# Train MSE: 0.45230299436603055
# Train RMSE: 0.672534753277502
# Train MAE: 0.19697297353777146
# Train r2: 0.9147099877150879
#
# Test MSE: 1.8411424145283772
# Test RMSE: 1.3568870308645364
# Test MAE: 0.5007000094494923
# Test r2: 0.69371118285578

# %%
### Grid Search
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html
grid = GridSearchCV(RandomForestRegressor(), cv=10, n_jobs=20, scoring="r2",
            param_grid={})
grid.fit(X_mat_train, y_train)

#print("Best parameters set found on development set:")
#print()
#print(grid.best_params_)
#print()
print("Grid scores on development set:")
print()
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
        % (mean, std * 2, params))
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Grid scores on development set:
#
# 0.620 (+/-0.272) for {}

# %%
grid_train_pred = grid.predict(X_mat_train)

print()
print("Test MSE: " + str(mean_squared_error(y_train, grid_train_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_train, grid_train_pred))))
print("Test MAE: " + str(mean_absolute_error(y_train, grid_train_pred)))
print("Test r2: " + str(r2_score(y_train, grid_train_pred)))
# Out:
# Test MSE: 0.3844075811602235
# Test RMSE: 0.6200061138087458
# Test MAE: 0.19250177344422212
# Test r2: 0.9275129111945779

# %%
grid_pred = grid.predict(X_mat_test)

print()
print("Test MSE: " + str(mean_squared_error(y_test, grid_pred)))
print("Test RMSE: " + str(np.sqrt(mean_squared_error(y_test, grid_pred))))
print("Test MAE: " + str(mean_absolute_error(y_test, grid_pred)))
print("Test r2: " + str(r2_score(y_test, grid_pred)))
# Out:
# Test MSE: 2.3953803374189477
# Test RMSE: 1.5477016306184301
# Test MAE: 0.49454079180370236
# Test r2: 0.6015092562263799

# %%
print(rf.feature_importances_)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 6.12857671e-05
#  4.12690538e-05 4.12215027e-06]

# %%
importances = rf.feature_importances_

# %%
categories = []
for t in enc.categories_:
    for c in t:
        categories.append(c)

# %%
for col in X_train.drop(columns=cats).columns:
    categories.append(col)
categories
# Out:
# ['Aberdeen',
#  'Abilene',
#  'Abington',
#  'Ada',
#  'Addison',
#  'Adelphi',
#  'Adrian',
#  'Aguadilla',
#  'Aiken',
#  'Akron',
#  'Alameda',
#  'Alamogordo',
#  'Alamosa',
#  'Albany',
#  'Albion',
#  'Albuquerque',
#  'Alcorn State',
#  'Alexander City',
#  'Alexandria',
#  'Alfred',
#  'Alhambra',
#  'Allen Park',
#  'Allendale',
#  'Allentown',
#  'Alliance',
#  'Alma',
#  'Alpena',
#  'Alpine',
#  'Altamonte Springs',
#  'Altoona',
#  'Altus',
#  'Alva',
#  'Alvin',
#  'Amarillo',
#  'Ambler',
#  'American Fork',
#  'Americus',
#  'Ames',
#  'Amherst',
#  'Amityville',
#  'Anaheim',
#  'Anchorage',
#  'Anderson',
#  'Angola',
#  'Angwin',
#  'Ankeny',
#  'Ann Arbor',
#  'Annandale',
#  'Annandale-On-Hudson',
#  'Annapolis',
#  'Annville',
#  'Anoka',
#  'Antioch',
#  'Apopka',
#  'Appleton',
#  'Aptos',
#  'Arcata',
#  'Archbold',
#  'Arecibo',
#  'Arkadelphia',
#  'Arkansas City',
#  'Arlington',
#  'Arlington Heights',
#  'Arnold',
#  'Arvada',
#  'Ashburn',
#  'Asheville',
#  'Ashland',
#  'Ashtabula',
#  'Ashwaubenon',
#  'Aston',
#  'Astoria',
#  'Atchison',
#  'Athens',
#  'Atherton',
#  'Atlanta',
#  'Auburn',
#  'Auburn Hills',
#  'Audubon',
#  'Augusta',
#  'Aurora',
#  'Austin',
#  'Austintown',
#  'Ave Maria',
#  'Avon Park',
#  'Avondale',
#  'Azusa',
#  'Babson Park',
#  'Bad Axe',
#  'Bainbridge',
#  'Bakersfield',
#  'Baldwin City',
#  'Baltimore',
#  'Bangor',
#  'Banner Elk',
#  'Bar Harbor',
#  'Barbourville',
#  'Barnesville',
#  'Barranquitas',
#  'Bartlesville',
#  'Batavia',
#  'Batesville',
#  'Baton Rouge',
#  'Battle Creek',
#  'Bay City',
#  'Bay Minette',
#  'Bayamon',
#  'Bayamón',
#  'Bayside',
#  'Baytown',
#  'Beachwood',
#  'Beaufort',
#  'Beaumont',
#  'Beaver Falls',
#  'Beaverton',
#  'Beckley',
#  'Bedford',
#  'Bedford Park',
#  'Beebe',
#  'Beeville',
#  'Bel Air',
#  'Bell',
#  'Bellefontaine',
#  'Belleville',
#  'Bellevue',
#  'Bellingham',
#  'Belmont',
#  'Beloit',
#  'Belton',
#  'Beltsville',
#  'Bemidji',
#  'Benbrook',
#  'Bend',
#  'Bennington',
#  'Bensalem',
#  'Benton Harbor',
#  'Bentonville',
#  'Berea',
#  'Berkeley',
#  'Berlin',
#  'Berrien Springs',
#  'Bessemer',
#  'Bethany',
#  'Bethesda',
#  'Bethlehem',
#  'Bettendorf',
#  'Beverly',
#  'Beverly Hills',
#  'Biddeford',
#  'Big Rapids',
#  'Big Spring',
#  'Billings',
#  'Biloxi',
#  'Binghamton',
#  'Birmingham',
#  'Bismarck',
#  'Blacksburg',
#  'Blackwood',
#  'Blaine',
#  'Blair',
#  'Blairsville',
#  'Bloomfield',
#  'Bloomfield Hills',
#  'Bloomingdale',
#  'Bloomington',
#  'Bloomsburg',
#  'Blountville',
#  'Blue Ash',
#  'Blue Bell',
#  'Blue Island',
#  'Blue Mountain',
#  'Blue Springs',
#  'Bluefield',
#  'Bluffton',
#  'Blytheville',
#  'Boaz',
#  'Boca Raton',
#  'Bohemia',
#  'Boiling Springs',
#  'Boise',
#  'Bolivar',
#  'Boone',
#  'Booneville',
#  'Bordentown',
#  'Borger',
#  'Bossier City',
#  'Boston',
#  'Bothell',
#  'Bottineau',
#  'Boulder',
#  'Bourbonnais',
#  'Bowie',
#  'Bowling Green',
#  'Boynton Beach',
#  'Bozeman',
#  'Bradenton',
#  'Bradford',
#  'Brainerd',
#  'Braintree',
#  'Branchburg',
#  'Branford',
#  'Brattleboro',
#  'Brecksville',
#  'Bremerton',
#  'Brenham',
#  'Brentwood',
#  'Brevard',
#  'Brick',
#  'Bridgeport',
#  'Bridgeton',
#  'Bridgeview',
#  'Bridgewater',
#  'Bridgton',
#  'Brighton',
#  'Bristol',
#  'Broadview Heights',
#  'Brockport',
#  'Brockton',
#  'Broken Arrow',
#  'Bronx',
#  'Bronxville',
#  'Brookfield',
#  'Brookings',
#  'Brookline',
#  'Brooklyn',
#  'Brooklyn Center',
#  'Brooklyn Heights',
#  'Brooklyn Park',
#  'Brookville',
#  'Broomall',
#  'Broomfield',
#  'Brownsburg',
#  'Brownsville',
#  'Brownwood',
#  'Brunswick',
#  'Bryan',
#  'Bryn Mawr',
#  'Buckhannon',
#  'Buena Vista',
#  'Buffalo',
#  'Buies Creek',
#  'Burbank',
#  'Burlington',
#  'Burnsville',
#  'Burr Ridge',
#  'Burton',
#  'Butler',
#  'Butte',
#  'Buzzards Bay',
#  'CANAL WINCHESTER',
#  'CHESTER',
#  'CLIFTON',
#  'Cable',
#  'Cadillac',
#  'Caguas',
#  'Calais',
#  'Caldwell',
#  'Calexico',
#  'California',
#  'Calmar',
#  'Calumet City',
#  'Cambridge',
#  'Camden',
#  'Campbell',
#  'Campbellsville',
#  'Canandaigua',
#  'Canonsburg',
#  'Canton',
#  'Canyon',
#  'Canyon Country',
#  'Cape Girardeau',
#  'Carbondale',
#  'Caribou',
#  'Carlinville',
#  'Carlisle',
#  'Carlsbad',
#  'Carneys Point',
#  'Caro',
#  'Carolina',
#  'Carrollton',
#  'Carson',
#  'Carson City',
#  'Carterville',
#  'Carthage',
#  'Cary',
#  'Casper',
#  'Casselberry',
#  'Castine',
#  'Castleton',
#  'Cathedral City',
#  'Cayey',
#  'Cazenovia',
#  'Cedar City',
#  'Cedar Falls',
#  'Cedar Hill',
#  'Cedar Rapids',
#  'Cedarville',
#  'Celina',
#  'Centennial',
#  'Center Valley',
#  'Centerville',
#  'Central',
#  'Centralia',
#  'Centreville',
#  'Cerritos',
#  'Chadron',
#  'Chalmette',
#  'Chambersburg',
#  'Chamblee',
#  'Champaign',
#  'Chandler',
#  'Chantilly',
#  'Chanute',
#  'Chapel Hill',
#  'Charleston',
#  'Charlotte',
#  'Charlotte Amalie',
#  'Charlottesville',
#  'Charlston',
#  'Chattanooga',
#  'Chelsea',
#  'Cheney',
#  'Cherry Hill',
#  'Chesapeake',
#  'Chester',
#  'Chesterfield',
#  'Chestertown',
#  'Chestnut Hill',
#  'Cheyenne',
#  'Cheyney',
#  'Chicago',
#  'Chicago Heights',
#  'Chickasha',
#  'Chico',
#  'Chicopee',
#  'Chillicothe',
#  'Chubbuck',
#  'Chula Vista',
#  'Cicero',
#  'Cincinnati',
#  'Circleville',
#  'Cisco',
#  'Citrus Heights',
#  'City of Industry',
#  'Claremont',
#  'Claremore',
#  'Clarendon',
#  'Clarion',
#  'Clarkesville',
#  'Clarksburg',
#  'Clarksville',
#  'Clawson',
#  'Clayton',
#  'Clearwater',
#  'Clemson',
#  'Cleveland',
#  'Clifton',
#  'Clifton Forge',
#  'Clinton',
#  'Clinton Township',
#  'Clive',
#  'Cloquet',
#  'Clovis',
#  'Clyde',
#  'Coachella',
#  'Coalinga',
#  'Cobleskill',
#  'Cochran',
#  'Cocoa',
#  "Coeur D'Alene",
#  "Coeur d'Alene",
#  'Coffeyville',
#  'Colby',
#  'Colchester',
#  'College Park',
#  'College Place',
#  'College Station',
#  'Collegedale',
#  'Collegeville',
#  'Collinsville',
#  'Colonial Heights',
#  'Colorado Springs',
#  'Colton',
#  'Columbia',
#  'Columbus',
#  'Commerce',
#  'Compton',
#  'Concord',
#  'Concordia',
#  'Conroe',
#  'Conway',
#  'Conyers',
#  'Cookeville',
#  'Coolidge',
#  'Coon Rapids',
#  'Coos Bay',
#  'Copley',
#  'Coral Gables',
#  'Coral Springs',
#  'Cordova',
#  'Corning',
#  'Corona',
#  'Corpus Christi',
#  'Corsicana',
#  'Cortland',
#  'Corvallis',
#  'Costa Mesa',
#  'Cottleville',
#  'Council Bluffs',
#  'Covington',
#  'Cranberry Township',
#  'Cranford',
#  'Cranston',
#  'Crawfordsville',
#  'Cresson',
#  'Creston',
#  'Crestview Hills',
#  'Crestwood',
#  'Crete',
#  'Cromwell',
#  'Crookston',
#  'Cross Lanes',
#  'Crystal Lake',
#  'Cullowhee',
#  'Culver City',
#  'Cumberland',
#  'Curtis',
#  'Cuthbert',
#  'Cutler Bay',
#  'Cuyahoga Falls',
#  'Cypress',
#  'Dahlonega',
#  'Dallas',
#  'Dalton',
#  'Danbury',
#  'Danvers',
#  'Danville',
#  'Darien',
#  'Davenport',
#  'Davidson',
#  'Davis',
#  'Davison',
#  'Dayton',
#  'Daytona Beach',
#  'De Pere',
#  'DeLand',
#  'DeSoto',
#  'Dearborn',
#  'Decatur',
#  'Decorah',
#  'Deerfield',
#  'Defiance',
#  'Dekalb',
#  'Del Rio',
#  'Delaware',
#  'Delhi',
#  'Delta',
#  'Demorest',
#  'Denham Springs',
#  'Denison',
#  'Denmark',
#  'Denton',
#  'Denver',
#  'Des Moines',
#  'Des Plaines',
#  'Detroit',
#  'Detroit Lakes',
#  'Devils Lake',
#  'Dickinson',
#  'Dickson City',
#  'Dillon',
#  'Dimondale',
#  'Dix Hills',
#  'Dixon',
#  'Dobbs Ferry',
#  'Dobson',
#  'Dodge City',
#  'Donaldson',
#  'Doral',
#  'Dorchester',
#  'Dothan',
#  'Douglas',
#  'Douglasville',
#  'Dover',
#  'Dowagiac',
#  'Downers Grove',
#  'Downingtown',
#  'Doylestown',
#  'Draper',
#  'Dryden',
#  'Du Bois',
#  'DuBois',
#  'Dublin',
#  'Dubuque',
#  'Dudley',
#  'Due West',
#  'Duluth',
#  'Dunbar',
#  'Dunmore',
#  'Dunwoody',
#  'Durango',
#  'Durant',
#  'Durham',
#  'Dyersburg',
#  'ERIAL',
#  'Eagan',
#  'Eagle Pass',
#  'Earth City',
#  'East Grand Forks',
#  'East Greenwich',
#  'East Hartford',
#  'East Lansing',
#  'East Liverpool',
#  'East Moline',
#  'East Peoria',
#  'East Providence',
#  'East Stroudsburg',
#  'East Windsor',
#  'Easton',
#  'Eau Claire',
#  'Eden Prairie',
#  'Edina',
#  'Edinboro',
#  'Edinburg',
#  'Edison',
#  'Edmond',
#  'Edwardsville',
#  'Egg Harbor Township',
#  'El Cajon',
#  'El Centro',
#  'El Dorado',
#  'El Monte',
#  'El Paso',
#  'El Reno',
#  'Elgin',
#  'Elizabeth',
#  'Elizabeth City',
#  'Elizabethtown',
#  'Elk River',
#  'Elkhart',
#  'Elkins',
#  'Elkins Park',
#  'Elko',
#  'Ellendale',
#  'Ellensburg',
#  'Ellisville',
#  'Ellsworth Air Force Base',
#  'Elmhurst',
#  'Elmira',
#  'Elon',
#  'Ely',
#  'Elyria',
#  'Emeryville',
#  'Emmitsburg',
#  'Emory',
#  'Emporia',
#  'Encino',
#  'Enfield',
#  'Englewood',
#  'Enid',
#  'Ennis',
#  'Enterprise',
#  'Ephraim',
#  'Erdenheim',
#  'Erie',
#  'Erlanger',
#  'Escanaba',
#  'Espanola',
#  'Essex Junction',
#  'Essington',
#  'Estherville',
#  'Eugene',
#  'Eunice',
#  'Eureka',
#  'Evanston',
#  'Evansville',
#  'Eveleth',
#  'Everett',
#  'Ewing',
#  'Exton',
#  'Fairbanks',
#  'Fairborn',
#  'Fairburn',
#  'Fairfax',
#  'Fairfield',
#  'Fairmont',
#  'Fairview Heights',
#  'Fairview Park',
#  'Fajardo',
#  'Fall River',
#  'Falls Church',
#  'Falls Creek',
#  'Fargo',
#  'Faribault',
#  'Farmers Branch',
#  'Farmingdale',
#  'Farmington',
#  'Farmington Hills',
#  'Farmville',
#  'Fayette',
#  'Fayetteville',
#  'Feasterville',
#  'Federal Way',
#  'Fennimore',
#  'Fenton',
#  'Fergus Falls',
#  'Fern Park',
#  'Ferrum',
#  'Fife',
#  'Findlay',
#  'Fitchburg',
#  'Flagstaff',
#  'Flat Rock',
#  'Flint',
#  'Florence',
#  'Florissant',
#  'Flowood',
#  'Flushing',
#  'Foley',
#  'Fond Du Lac',
#  'Fond du Lac',
#  'Fontana',
#  'Ford City',
#  'Forest City',
#  'Forest Grove',
#  'Forest Hills',
#  'Forest Park',
#  'Forrest City',
#  'Fort  Morgan',
#  'Fort Collins',
#  'Fort Dodge',
#  'Fort Kent',
#  'Fort Lauderdale',
#  'Fort Mitchell',
#  'Fort Myers',
#  'Fort Pierce',
#  'Fort Scott',
#  'Fort Smith',
#  'Fort Valley',
#  'Fort Washington',
#  'Fort Wayne',
#  'Fort Worth',
#  'Forty Fort',
#  'Fountain Valley',
#  'Frackville',
#  'Framingham',
#  'Frankfort',
#  'Franklin',
#  'Franklin Springs',
#  'Frederick',
#  'Fredericksburg',
#  'Fredonia',
#  'Freehold',
#  'Freeport',
#  'Fremont',
#  'French Camp',
#  'Fresno',
#  'Friendswood',
#  'Frostburg',
#  'Ft Myers',
#  'Ft Worth',
#  'Ft. Washington',
#  'Ft. Wayne',
#  'Fullerton',
#  'Fulton',
#  'Gaffney',
#  'Gainesville',
#  'Gaithersburg',
#  'Galesburg',
#  'Gallatin',
#  'Gallipolis',
#  'Galloway',
#  'Gallup',
#  'Galveston',
#  'Gambier',
#  'Garden City',
#  'Garden Grove',
#  'Gardena',
#  'Gardner',
#  'Garland',
#  'Gary',
#  'Gastonia',
#  'Geneseo',
#  'Geneva',
#  'Georgetown',
#  'Gettysburg',
#  'Getzville',
#  'Gilroy',
#  'Gladstone',
#  'Glassboro',
#  'Glen Allen',
#  'Glen Burnie',
#  'Glen Ellyn',
#  'Glendale',
#  'Glendive',
#  'Glendora',
#  'Glenside',
#  'Glenville',
#  'Glenwood Springs',
#  'Gloucester',
#  'Godfrey',
#  'Gold River',
#  'Golden',
#  'Goldsboro',
#  'Gonzales',
#  'Goodland',
#  'Goodman',
#  'Goodwell',
#  'Goshen',
#  'Graceville',
#  'Grambling',
#  'Granada Hills',
#  'Grand Chute',
#  'Grand Forks',
#  'Grand Island',
#  'Grand Junction',
#  'Grand Prairie',
#  'Grand Rapids',
#  'Granger',
#  'Granite Falls',
#  'Graniteville',
#  'Grants',
#  'Grants Pass',
#  'Granville',
#  'Grayslake',
#  'Grayson',
#  'Great Barrington',
#  'Great Bend',
#  'Great Falls',
#  'Greeley',
#  'Green Bay',
#  'Greencastle',
#  'Greeneville',
#  'Greenfield',
#  'Greensboro',
#  'Greensburg',
#  'Greenville',
#  'Greenwood',
#  'Grenada',
#  'Gresham',
#  'Gretna',
#  'Griffin',
#  'Grinnell',
#  'Groton',
#  'Grove City',
#  'Groveport',
#  'Guayama',
#  'Guaynabo',
#  'Gulfport',
#  'Gunnison',
#  'Gurabo',
#  'Gwynedd Valley',
#  'HASKELL',
#  'Hackensack',
#  'Hackettstown',
#  'Hagerstown',
#  'Hamburg',
#  'Hamden',
#  'Hamilton',
#  'Hammond',
#  'Hampden-Sydney',
#  'Hampton',
#  'Hanceville',
#  'Hancock',
#  'Hanford',
#  'Hannibal',
#  'Hanover',
#  'Hanover Park',
#  'Happy Valley',
#  'Harlingen',
#  'Harriman',
#  'Harrisburg',
#  'Harrison',
#  'Harrisonburg',
#  'Harrogate',
#  'Hartford',
#  'Hartsville',
#  'Hastings',
#  'Hato Rey',
#  'Hattiesburg',
#  'Hauppauge',
#  'Haverford',
#  'Haverhill',
#  'Haviland',
#  'Havre',
#  'Hawkins',
#  'Hawthorne',
#  'Hays',
#  'Hayward',
#  'Hazard',
#  'Hazelwood',
#  'Hazle Township',
#  'Hazleton',
#  'Heath',
#  'Helena',
#  'Hemet',
#  'Hempstead',
#  'Henderson',
#  'Henniker',
#  'Henrico',
#  'Herkimer',
#  'Hershey',
#  'Hesperia',
#  'Hesston',
#  'Hialeah',
#  'Hibbing',
#  'Hickory',
#  'Hicksville',
#  'High Point',
#  'Highland',
#  'Highland Heights',
#  'Hilliard',
#  'Hillsboro',
#  'Hillside',
#  'Hilo',
#  'Hiram',
#  'Hobbs',
#  'Hoboken',
#  'Holiday',
#  'Holland',
#  'Holly Springs',
#  'Hollywood',
#  'Holyoke',
#  'Homestead',
#  'Honolulu',
#  'Hooksett',
#  'Hope',
#  'Hopkins',
#  'Hopkinsville',
#  'Horn Lake',
#  'Hot Springs',
#  'Houghton',
#  'Houma',
#  'Houston',
#  'Howell',
#  'Hudson',
#  'Humacao',
#  'Huntingdon',
#  'Huntington',
#  'Huntington Beach',
#  'Huntington Park',
#  'Huntsville',
#  'Huron',
#  'Hurst',
#  'Hutchinson',
#  'Hyannis',
#  'Hyde Park',
#  'Idabel',
#  'Idaho Falls',
#  'Ilion',
#  'Immaculata',
#  'Ina',
#  'Incline Village',
#  'Independence',
#  'Indiana',
#  'Indianapolis',
#  'Indianola',
#  'Inglewood',
#  'Institute',
#  'International Falls',
#  'Inver Grove Heights',
#  'Iola',
#  'Iowa City',
#  'Iowa Falls',
#  'Ipswich',
#  'Ironton',
#  'Ironwood',
#  'Irvine',
#  'Irving',
#  'Irwindale',
#  'Iselin',
#  'Ithaca',
#  'Itta Bena',
#  'Jackson',
#  'Jacksonville',
#  'Jamaica',
#  'Jamestown',
#  'Janesville',
#  'Jasper',
#  'Jefferson',
#  'Jefferson City',
#  'Jeffersonville',
#  'Jenkintown',
#  'Jenks',
#  'Jersey City',
#  'Johnson',
#  'Johnson City',
#  'Johnston',
#  'Johnstown',
#  'Joliet',
#  'Jonesboro',
#  'Joplin',
#  'Joshua Tree',
#  'Juneau',
#  'Kahului',
#  'Kalamazoo',
#  'Kalispell',
#  'Kaneohe',
#  'Kankakee',
#  'Kansas City',
#  'Kapolei',
#  'Kearney',
#  'Keene',
#  'Kenansville',
#  'Kenilworth',
#  'Kenmore',
#  'Kenner',
#  'Kennesaw',
#  'Kenosha',
#  'Kent',
#  'Kentfield',
#  'Kentwood',
#  'Kerrville',
#  'Kettering',
#  'Keuka Park',
#  'Key West',
#  'Keyser',
#  'Kilgore',
#  'Killeen',
#  'King of Prussia',
#  'Kingman',
#  'Kings Point',
#  'Kingston',
#  'Kingsville',
#  'Kirkland',
#  'Kirksville',
#  'Kirkwood',
#  'Kirtland',
#  'Kissimmee',
#  'Kittanning',
#  'Klamath Falls',
#  'Knoxville',
#  'Kokomo',
#  'Kutztown',
#  'LAUDERHILL',
#  'La Crosse',
#  'La Grande',
#  'La Jolla',
#  'La Joya',
#  'La Junta',
#  'La Mesa',
#  'La Mirada',
#  'La Plata',
#  'La Plume',
#  'La Quinta',
#  'La Verne',
#  'Lacey',
#  'Laconia',
#  'Lafayette',
#  'Lagrange',
#  'Laguna Beach',
#  'Laie',
#  'Lake Charles',
#  'Lake City',
#  'Lake Elmo',
#  'Lake Forest',
#  'Lake Havasu City',
#  'Lake Jackson',
#  'Lake Katrine',
#  'Lake Mary',
#  'Lake Milton',
#  'Lake Oswego',
#  'Lake Wales',
#  'Lake Worth',
#  'Lakeland',
#  'Lakeville',
#  'Lakewood',
#  'Lamar',
#  'Lamoni',
#  'Lancaster',
#  'Landover',
#  'Langhorne',
#  'Langston',
#  'Lanham',
#  'Lansing',
#  'Laramie',
#  'Laredo',
#  'Largo',
#  'Las Cruces',
#  'Las Vegas',
#  'Lathrop',
#  'Latrobe',
#  'Lauderdale Lakes',
#  'Lauderhill',
#  'Laurel',
#  'Laurel Springs',
#  'Laurinburg',
#  'Lawrence',
#  'Lawrenceville',
#  'Lawton',
#  'Layton',
#  'Leavenworth',
#  'Lebanon',
#  "Lee's Summit",
#  'Leesburg',
#  'Lehman',
#  'Lemont Furnace',
#  'Lenexa',
#  'Lester',
#  'Levelland',
#  ...]

# %%
coefs = pd.SparseDataFrame(np.array(categories).reshape(1,-1), columns=importances)
coefs
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   """Entry point for launching an IPython kernel.
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/sparse/frame.py:745: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5997: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(data).__finalize__(self)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:392: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return cls(data, **kwargs)
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000  ...        0.000067        0.000044        0.000041  \
# 0  FIRSTGEN_DEATH_YR8_RT  ...  CIPTFBSANNUAL3  CIPTFBSANNUAL4  CIPTFBSANNUAL5
#
#          0.000032 0.000892 0.000080 0.000048 0.000061 0.000041 0.000004
# 0  CIPTFBSANNUAL6  MTHCMP1  MTHCMP2  MTHCMP3  MTHCMP4  MTHCMP5  MTHCMP6
#
# [1 rows x 4912 columns]

# %%
coefs.sort_index(axis=1, inplace=True)
coefs
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/sparse/frame.py:745: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5997: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(data).__finalize__(self)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:392: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return cls(data, **kwargs)
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000               0.000000               0.000000  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                 0.000000  ... 0.018731      0.021215   0.027662  \
# 0  FIRSTGEN_DEATH_YR8_RT  ...     54.0  NOPELL_YR3_N  AVGFACSAL
#
#                   0.028468   0.029588          0.040419   0.075574  \
# 0  LO_INC_COMP_ORIG_YR2_RT  Lewisburg  COMP_ORIG_YR3_RT  PELL_EVER
#
#            0.088988          0.090842 0.110388
# 0  COMP_ORIG_YR2_RT  UNKN_ORIG_YR4_RT   FAMINC
#
# [1 rows x 4912 columns]

# %%
least = coefs.iloc[:,:10]
least
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
#                      0.0                    0.0                    0.0  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                      0.0                    0.0                    0.0  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                      0.0                    0.0                    0.0  \
# 0  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT  FIRSTGEN_DEATH_YR8_RT
#
#                      0.0
# 0  FIRSTGEN_DEATH_YR8_RT

# %%
most = coefs.iloc[:,-10:]
most
# Out:
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/sparse/frame.py:745: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5997: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(data).__finalize__(self)
# /Users/Mattdintino/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
#   0.018731      0.021215   0.027662                 0.028468   0.029588  \
# 0     54.0  NOPELL_YR3_N  AVGFACSAL  LO_INC_COMP_ORIG_YR2_RT  Lewisburg
#
#            0.040419   0.075574          0.088988          0.090842 0.110388
# 0  COMP_ORIG_YR3_RT  PELL_EVER  COMP_ORIG_YR2_RT  UNKN_ORIG_YR4_RT   FAMINC
