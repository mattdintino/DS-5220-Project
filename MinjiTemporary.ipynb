# %%
import pandas as pd
import random
import os
import numpy as np
from sklearn.model_selection import train_test_split

# %%
frames = [
#     df_96, df_97, df_98, df_99, df_00,
#     df_01, df_02, df_03, df_04, df_05,
#     df_06, 
#     df_07, df_08, df_09, df_10,
#     df_11, 
    df_12, 
    df_13, df_14, 
#     df_15, df_16, df_17
]

# %%
# The data to load
# df_96 = "CollegeScorecard_Raw_Data/MERGED1996_97_PP.csv"
# df_97 = "CollegeScorecard_Raw_Data/MERGED1997_98_PP.csv"
# df_98 = "CollegeScorecard_Raw_Data/MERGED1998_99_PP.csv"
# df_99 = "CollegeScorecard_Raw_Data/MERGED1999_00_PP.csv"
# df_00 = "CollegeScorecard_Raw_Data/MERGED2000_01_PP.csv"
# df_01 = "CollegeScorecard_Raw_Data/MERGED2001_02_PP.csv"
# df_02 = "CollegeScorecard_Raw_Data/MERGED2002_03_PP.csv"
# df_03 = "CollegeScorecard_Raw_Data/MERGED2003_04_PP.csv"
# df_04 = "CollegeScorecard_Raw_Data/MERGED2004_05_PP.csv"
# df_05 = "CollegeScorecard_Raw_Data/MERGED2005_06_PP.csv"
# df_06 = "CollegeScorecard_Raw_Data/MERGED2006_07_PP.csv"
# df_07 = "CollegeScorecard_Raw_Data/MERGED2007_08_PP.csv"
# df_08 = "CollegeScorecard_Raw_Data/MERGED2008_09_PP.csv"
# df_09 = "CollegeScorecard_Raw_Data/MERGED2009_10_PP.csv"
# df_10 = "CollegeScorecard_Raw_Data/MERGED2010_11_PP.csv"
# df_11 = "CollegeScorecard_Raw_Data/MERGED2011_12_PP.csv"
df_12 = "CollegeScorecard_Raw_Data/MERGED2012_13_PP.csv"
df_13 = "CollegeScorecard_Raw_Data/MERGED2013_14_PP.csv"
df_14 = "CollegeScorecard_Raw_Data/MERGED2014_15_PP.csv"
# df_15 = "CollegeScorecard_Raw_Data/MERGED2015_16_PP.csv"
# df_16 = "CollegeScorecard_Raw_Data/MERGED2016_17_PP.csv"
# df_17 = "CollegeScorecard_Raw_Data/MERGED2017_18_PP.csv"

# %%
# college data dictionary
"""
Had to give a full path to avoid permission problem
"""
collegeDict= pd.read_excel('C:/Users/minji/OneDrive/Documents/2019Fall/SML/Project/jupyter/DS-5220-Project/CollegeScorecard_Raw_Data/CollegeScorecardDataDictionary.xlsx', sheet_name='data_dictionary')

# %%
collegeDict[collegeDict['dev-category']=='earnings']
# Out:
#                                    NAME OF DATA ELEMENT dev-category  \
# 1845           Count of students in the earnings cohort     earnings
# 1878  Number of students not working and not enrolle...     earnings
# 1879  Number of students working and not enrolled 10...     earnings
# 1880  Mean earnings of students working and not enro...     earnings
# 1881  Median earnings of students working and not en...     earnings
# 1882  10th percentile of earnings of students workin...     earnings
# 1883  25th percentile of earnings of students workin...     earnings
# 1884  75th percentile of earnings of students workin...     earnings
# 1885  90th percentile of earnings of students workin...     earnings
# 1886  Standard deviation of earnings of students wor...     earnings
# 1887  Number of students working and not enrolled 10...     earnings
# 1888  Number of students working and not enrolled 10...     earnings
# 1889  Number of students working and not enrolled 10...     earnings
# ...

# %%
# Random selection !!! Need to do stratified sample for selecting data according to each state.
def fileRead(filename): 
    # Count the lines
    num_lines = sum(1 for l in open(filename))

    # Sample size - in this case ~10%
    size = int(num_lines / 10)

    # The row indices to skip - make sure 0 is not included to keep the header!
    skip_idx = random.sample(range(1, num_lines), num_lines - size)

    # Read the data
    data = pd.read_csv(filename, skiprows=skip_idx)
    return data

# %%
# df_96 = fileRead(df_96)
# df_97 = fileRead(df_97)
# df_98 = fileRead(df_98)
# df_99 = fileRead(df_99)
# df_00 = fileRead(df_00)
# df_01 = fileRead(df_01)
# df_02 = fileRead(df_02)
# df_03 = fileRead(df_03)
# df_04 = fileRead(df_04)
# df_05 = fileRead(df_05)
# df_06 = fileRead(df_06)
# df_07 = fileRead(df_07)
# df_08 = fileRead(df_08)
# df_09 = fileRead(df_09)
# df_10 = fileRead(df_10)
# df_11 = fileRead(df_11)
df_12 = fileRead(df_12)
df_13 = fileRead(df_13)
df_14 = fileRead(df_14)
# df_15 = fileRead(df_15)
# df_16 = fileRead(df_16)
# df_17 = fileRead(df_17)
# Out:
# c:\users\minji\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df_10.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Columns: 1977 entries, UNITID to OMENRUP_PARTTIME_POOLED_SUPP
# dtypes: float64(813), int64(10), object(1154)
# memory usage: 7.9+ MB

# %%
# add the dataframes of 2012, 13,14 years and save them into 'data'
data = pd.concat(frames)

# %%
# Replace privacysuppressed to nan. It's at DEATH_YR2_RT variable, Percent died within 2 years at original institution
data = data.replace('PrivacySuppressed', np.nan) 
print(data.shape)
# Out:
# (2326, 1977)

# %%
list(data.columns)
# Out:
# ['UNITID',
#  'INSTNM',
#  'CITY',
#  'ACCREDAGENCY',
#  'SCH_DEG',
#  'HCM2',
#  'MAIN',
#  'NUMBRANCH',
#  'PREDDEG',
#  'HIGHDEG',
#  'CONTROL',
#  'ST_FIPS',
#  'REGION',
#  'LOCALE',
#  'LOCALE2',
#  'CCBASIC',
#  'CCUGPROF',
#  'CCSIZSET',
#  'HBCU',
#  'PBI',
#  'ANNHI',
#  'TRIBAL',
#  'AANAPII',
#  'HSI',
#  'NANTI',
#  'MENONLY',
#  'WOMENONLY',
#  'RELAFFIL',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SATVR25',
#  'SATVR75',
#  'SATMT25',
#  'SATMT75',
#  'SATWR25',
#  'SATWR75',
#  'SATVRMID',
#  'SATMTMID',
#  'SATWRMID',
#  'ACTCM25',
#  'ACTCM75',
#  'ACTEN25',
#  'ACTEN75',
#  'ACTMT25',
#  'ACTMT75',
#  'ACTWR25',
#  'ACTWR75',
#  'ACTCMMID',
#  'ACTENMID',
#  'ACTMTMID',
#  'ACTWRMID',
#  'SAT_AVG',
#  'SAT_AVG_ALL',
#  'PCIP01',
#  'PCIP03',
#  'PCIP04',
#  'PCIP05',
#  'PCIP09',
#  'PCIP10',
#  'PCIP11',
#  'PCIP12',
#  'PCIP13',
#  'PCIP14',
#  'PCIP15',
#  'PCIP16',
#  'PCIP19',
#  'PCIP22',
#  'PCIP23',
#  'PCIP24',
#  'PCIP25',
#  'PCIP26',
#  'PCIP27',
# ...

# %%
# Drop the columns

"""
Manually selected columns:
8-digit OPE ID for institution, 6-digit OPE ID for institution, State postcode, 
ZIP code, URL for institution's homepage, URL for institution's net price calculator

Full of null columns:
see the code below
"""

# Drop manually selected columns

drop_columns=['OPEID','OPEID6','STABBR','ZIP','INSTURL','NPCURL','LATITUDE','LONGITUDE'] 
data = data.drop(columns=drop_columns)
# Out:
# (2326, 1969)

# %%
# Drop columns full of null
data= data.dropna(axis = 'columns', how='all')
data.shape
# Out:
# (2326, 1657)

# %%
# Drop row full of null

# %%
# test size: 0.33
